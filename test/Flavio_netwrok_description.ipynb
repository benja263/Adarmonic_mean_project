# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Final_dataset.csv', index_col=0)
df
# Out:
#                  author         publish_date  following  followers post_type  \
# 1            1D_NICOLE_  2015-11-26 22:20:00         48         40   RETWEET
# 2            1D_NICOLE_  2015-11-26 22:35:00         48         40   RETWEET
# 3            1D_NICOLE_  2015-09-06 15:26:00         59         53     TWEET
# 4            1D_NICOLE_  2015-09-06 15:30:00         59         53     TWEET
# 5            1D_NICOLE_  2015-09-06 15:33:00         59         53     TWEET
# 6           4EVER_SUSAN  2015-12-16 00:51:00         76         60     TWEET
# 7           4EVER_SUSAN  2015-12-16 01:00:00         76         60     TWEET
# 8           4EVER_SUSAN  2015-12-16 01:06:00         76         60     TWEET
# 9           4EVER_SUSAN  2015-12-16 01:10:00         76         60     TWEET
# 10          4EVER_SUSAN  2015-12-16 01:11:00         76         60     TWEET
# 11          4EVER_SUSAN  2015-12-16 01:14:00         76         60     TWEET
# ...

# %%
topics = df.topic.value_counts().index
# Out:
# Index(['Trump', 'Sports', 'Black', 'Entertainment', 'Health', 'Crime', 'Islam',
#        'Foreign Countries', 'Trump Adversaries', 'Patriot', 'Fukushima'],
#       dtype='object')

# %%
for topic in topics:
    df.tweet_text[df.topic == topic]
# Out:
# 1         #FoodPoisoning is not a joke! #Walmart #KochFa...
# 3         I want my little parrot to speak at last!!! #D...
# 6         U don't like Carson - u r racist, U don't like...
# 7         Some idiotic show on MTV would be more informa...
# 8         God is not a franchise of the Republican Party...
# 11        Trump is an magnate and he doesn’t care about ...
# 12        #CNNDebate #VegasGOPDebate All these speeches ...
# 13        #CNNDebate Do we really need another #GOPDebat...
# 14        Is there a drinking game for the #GOPDebate? #...
# 15        #CNNDebate #VegasGOPDebate Today we’ll hear a ...
# 16        Will corrupted politicians talk about corrupti...
# 17        #CNNDebate #GOPDebate If Jeb loses his wife wi...
# 18         It’s just a baby talk #GOPDebate #VegasGOPDebate
# 19        Common sense isn’t the best friend of the GOP ...
# 20        #VegasGOPDebate #GOPDebate If Carson doesn't s...
# 21           Donald Trump at the #GOPDebate #VegasGOPDebate
# ...
